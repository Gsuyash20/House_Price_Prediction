# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Delhi_v2.csv')

# %%
data.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0       price  \
# 0              0   5600000.0
# 1              1   8800000.0
# 2              2  16500000.0
# 3              3   3810000.0
# 4              4   6200000.0
# ...          ...         ...
# 7733        7733   7900000.0
# 7734        7734   4510000.0
# 7735        7735   7000000.0
# 7736        7736   6500000.0
# 7737        7737   6500000.0
#
#                                                 Address    area   latitude  \
# 0                     Noida Extension, Noida, Delhi NCR  1350.0  28.608850
# 1                         Sector 79, Gurgaon, Delhi NCR  1490.0  28.374236
# 2                        Vaishali, Ghaziabad, Delhi NCR  2385.0  28.645769
# 3     Link Road, F Block, Sector 50, Noida, Uttar Pr...  1050.0  28.566914
# 4     Jaypee Pavilion Court Sector 128, Noida, Secto...  1350.0  28.520732
# ...                                                 ...     ...        ...
# ...

# %%
data.shape
# Out:
# (7738, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   Address           7738 non-null   object
#  3   area              7738 non-null   float64
#  4   latitude          7738 non-null   float64
#  5   longitude         7738 non-null   float64
#  6   Bedrooms          7738 non-null   float64
#  7   Bathrooms         7738 non-null   float64
#  8   Balcony           5166 non-null   float64
#  9   Status            7164 non-null   object
#  10  neworold          7738 non-null   object
#  11  parking           2612 non-null   float64
#  12  Furnished_status  4124 non-null   object
#  13  Lift              1733 non-null   float64
#  14  Landmarks         2759 non-null   object
#  15  type_of_building  7738 non-null   object
# ...

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# Unnamed: 0
# 0       1
# 5198    1
# 5166    1
# 5165    1
# 5164    1
#        ..
# 2575    1
# 2574    1
# 2573    1
# 2572    1
# 7737    1
# Name: count, Length: 7738, dtype: int64
# ********************
# price
# 4500000.0    290
# 3500000.0    252
# 4000000.0    247
# 6000000.0    243
# 5500000.0    223
#             ...
# 6860000.0      1
# 5290000.0      1
# 8450000.0      1
# 7670000.0      1
# 4510000.0      1
# Name: count, Length: 584, dtype: int64
# ********************
# Address
# Raj Nagar Extension, Ghaziabad, Delhi NCR                                     163
# Indirapuram, Ghaziabad, Delhi NCR                                             152
# Greater Noida West, Greater Noida, Delhi NCR                                  100
# Noida Extension, Noida, Delhi NCR                                              63
# NH 24, Ghaziabad, Delhi NCR                                                    61
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0             0
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             2572
# Status               574
# neworold               0
# parking             5126
# Furnished_status    3614
# Lift                6005
# Landmarks           4979
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
data.drop(columns=['Lift', 'parking', 'Landmarks', 'Balcony'], inplace=True)

# %%
data.describe()
# Out:
#         Unnamed: 0         price         area     latitude    longitude  \
# count  7738.000000  7.738000e+03  7738.000000  7738.000000  7738.000000
# mean   3868.500000  8.320635e+06  1409.506591    28.552092    77.273476
# std    2233.912524  7.223197e+06   718.929581     0.107420     0.180606
# min       0.000000  1.700000e+06   501.000000    28.240023    76.884101
# 25%    1934.250000  4.200000e+06   990.000000    28.455539    77.078590
# 50%    3868.500000  6.000000e+06  1250.000000    28.574637    77.345320
# 75%    5802.750000  9.500000e+06  1650.000000    28.642520    77.421054
# max    7737.000000  8.500000e+07  9500.000000    28.799748    77.688028
#
#           Bedrooms    Bathrooms    Price_sqft
# count  7738.000000  7738.000000   7738.000000
# mean      2.708193     2.501163   5543.660241
# std       0.877026     0.867050   2408.659307
# min       2.000000     2.000000   2100.000000
# 25%       2.000000     2.000000   3950.986915
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   Address           7738 non-null   object
#  3   area              7738 non-null   float64
#  4   latitude          7738 non-null   float64
#  5   longitude         7738 non-null   float64
#  6   Bedrooms          7738 non-null   float64
#  7   Bathrooms         7738 non-null   float64
#  8   Status            7164 non-null   object
#  9   neworold          7738 non-null   object
#  10  Furnished_status  4124 non-null   object
#  11  type_of_building  7738 non-null   object
#  12  desc              7738 non-null   object
#  13  Price_sqft        7738 non-null   float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 846.5+ KB

# %%
data['Status'] = data['Status'].fillna('Ready to Move')

# %%
data['Furnished_status'] = data['Furnished_status'].fillna('Unfurnished')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   Address           7738 non-null   object
#  3   area              7738 non-null   float64
#  4   latitude          7738 non-null   float64
#  5   longitude         7738 non-null   float64
#  6   Bedrooms          7738 non-null   float64
#  7   Bathrooms         7738 non-null   float64
#  8   Status            7738 non-null   object
#  9   neworold          7738 non-null   object
#  10  Furnished_status  7738 non-null   object
#  11  type_of_building  7738 non-null   object
#  12  desc              7738 non-null   object
#  13  Price_sqft        7738 non-null   float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 846.5+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# Unnamed: 0
# 0       1
# 5198    1
# 5166    1
# 5165    1
# 5164    1
#        ..
# 2575    1
# 2574    1
# 2573    1
# 2572    1
# 7737    1
# Name: count, Length: 7738, dtype: int64
# ********************
# price
# 4500000.0    290
# 3500000.0    252
# 4000000.0    247
# 6000000.0    243
# 5500000.0    223
#             ...
# 6860000.0      1
# 5290000.0      1
# 8450000.0      1
# 7670000.0      1
# 4510000.0      1
# Name: count, Length: 584, dtype: int64
# ********************
# Address
# Raj Nagar Extension, Ghaziabad, Delhi NCR                                     163
# Indirapuram, Ghaziabad, Delhi NCR                                             152
# Greater Noida West, Greater Noida, Delhi NCR                                  100
# Noida Extension, Noida, Delhi NCR                                              63
# NH 24, Ghaziabad, Delhi NCR                                                    61
# ...

# %%
data['Address'].value_counts()
# Out:
# Address
# Raj Nagar Extension, Ghaziabad, Delhi NCR                                     163
# Indirapuram, Ghaziabad, Delhi NCR                                             152
# Greater Noida West, Greater Noida, Delhi NCR                                  100
# Noida Extension, Noida, Delhi NCR                                              63
# NH 24, Ghaziabad, Delhi NCR                                                    61
#                                                                              ...
# e block sector 57, Sector 57, Gurgaon, Delhi NCR                                1
# Ramakrishna apartment, Indraprastha Extension, New Delhi - East, Delhi NCR      1
# Rajnagar Extension Gahziabad, Raj Nagar Extension, Ghaziabad, Delhi NCR         1
# Rajendra Park, Rajendra Park, Gurgaon, Delhi NCR                                1
# sandal apartment, Shalimar Garden Extension 1, Ghaziabad, Delhi NCR             1
# Name: count, Length: 4145, dtype: int64

# %%
data['Address'] = data['Address'].apply(lambda x:x.strip())
address_count = data['Address'].value_counts()

# %%
address_count
# Out:
# Address
# Raj Nagar Extension, Ghaziabad, Delhi NCR                                     163
# Indirapuram, Ghaziabad, Delhi NCR                                             152
# Greater Noida West, Greater Noida, Delhi NCR                                  100
# Noida Extension, Noida, Delhi NCR                                              63
# NH 24, Ghaziabad, Delhi NCR                                                    61
#                                                                              ...
# e block sector 57, Sector 57, Gurgaon, Delhi NCR                                1
# Ramakrishna apartment, Indraprastha Extension, New Delhi - East, Delhi NCR      1
# Rajnagar Extension Gahziabad, Raj Nagar Extension, Ghaziabad, Delhi NCR         1
# Rajendra Park, Rajendra Park, Gurgaon, Delhi NCR                                1
# sandal apartment, Shalimar Garden Extension 1, Ghaziabad, Delhi NCR             1
# Name: count, Length: 4145, dtype: int64

# %%
address_count_less10 = address_count[address_count<=10]
address_count_less10
# Out:
# Address
# Surajpur, Greater Noida, Delhi NCR                                            10
# Sector 21C, Faridabad, Delhi NCR                                              10
# Sector 107, Gurgaon, Delhi NCR                                                10
# Sector 90, Gurgaon, Delhi NCR                                                 10
# Sector 79, Noida, Delhi NCR                                                   10
#                                                                               ..
# e block sector 57, Sector 57, Gurgaon, Delhi NCR                               1
# Ramakrishna apartment, Indraprastha Extension, New Delhi - East, Delhi NCR     1
# Rajnagar Extension Gahziabad, Raj Nagar Extension, Ghaziabad, Delhi NCR        1
# Rajendra Park, Rajendra Park, Gurgaon, Delhi NCR                               1
# sandal apartment, Shalimar Garden Extension 1, Ghaziabad, Delhi NCR            1
# Name: count, Length: 4056, dtype: int64

# %%
data['Address'] = data['Address'].apply(lambda x: 'other' if x in address_count_less10 else x)

# %%
data['Address'].value_counts()
# Out:
# Address
# other                                           5621
# Raj Nagar Extension, Ghaziabad, Delhi NCR        163
# Indirapuram, Ghaziabad, Delhi NCR                152
# Greater Noida West, Greater Noida, Delhi NCR     100
# Noida Extension, Noida, Delhi NCR                 63
#                                                 ...
# Sector 86, Faridabad, Delhi NCR                   11
# Sector 86, Gurgaon, Delhi NCR                     11
# Sector 70, Gurgaon, Delhi NCR                     11
# Sector 119, Noida, Delhi NCR                      11
# Sector 78, Faridabad, Delhi NCR                   11
# Name: count, Length: 90, dtype: int64

# %%
data.describe()
# Out:
#         Unnamed: 0         price         area     latitude    longitude  \
# count  7738.000000  7.738000e+03  7738.000000  7738.000000  7738.000000
# mean   3868.500000  8.320635e+06  1409.506591    28.552092    77.273476
# std    2233.912524  7.223197e+06   718.929581     0.107420     0.180606
# min       0.000000  1.700000e+06   501.000000    28.240023    76.884101
# 25%    1934.250000  4.200000e+06   990.000000    28.455539    77.078590
# 50%    3868.500000  6.000000e+06  1250.000000    28.574637    77.345320
# 75%    5802.750000  9.500000e+06  1650.000000    28.642520    77.421054
# max    7737.000000  8.500000e+07  9500.000000    28.799748    77.688028
#
#           Bedrooms    Bathrooms    Price_sqft
# count  7738.000000  7738.000000   7738.000000
# mean      2.708193     2.501163   5543.660241
# std       0.877026     0.867050   2408.659307
# min       2.000000     2.000000   2100.000000
# 25%       2.000000     2.000000   3950.986915
# ...

# %%
data.shape
# Out:
# (7738, 14)

# %%
data.drop(columns=['Unnamed: 0', 'latitude', 'longitude'], inplace = True)

# %%
data
# Out:
#            price                                            Address    area  \
# 0      5600000.0                  Noida Extension, Noida, Delhi NCR  1350.0
# 1      8800000.0                      Sector 79, Gurgaon, Delhi NCR  1490.0
# 2     16500000.0                     Vaishali, Ghaziabad, Delhi NCR  2385.0
# 3      3810000.0                                              other  1050.0
# 4      6200000.0                                              other  1350.0
# ...          ...                                                ...     ...
# 7733   7900000.0                  Indirapuram, Ghaziabad, Delhi NCR  1095.0
# 7734   4510000.0                                              other  1060.0
# 7735   7000000.0           Crossings Republik, Ghaziabad, Delhi NCR  1898.0
# 7736   6500000.0  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...  1400.0
# 7737   6500000.0                                              other  1750.0
#
# ...

# %%
data.drop(columns=['type_of_building', 'desc', 'neworold'], inplace = True)

# %%
data
# Out:
#            price                                            Address    area  \
# 0      5600000.0                  Noida Extension, Noida, Delhi NCR  1350.0
# 1      8800000.0                      Sector 79, Gurgaon, Delhi NCR  1490.0
# 2     16500000.0                     Vaishali, Ghaziabad, Delhi NCR  2385.0
# 3      3810000.0                                              other  1050.0
# 4      6200000.0                                              other  1350.0
# ...          ...                                                ...     ...
# 7733   7900000.0                  Indirapuram, Ghaziabad, Delhi NCR  1095.0
# 7734   4510000.0                                              other  1060.0
# 7735   7000000.0           Crossings Republik, Ghaziabad, Delhi NCR  1898.0
# 7736   6500000.0  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...  1400.0
# 7737   6500000.0                                              other  1750.0
#
# ...

# %% [markdown]
# ## Cleaned Data

# %%
data.head()
# Out:
#         price                            Address    area  Bedrooms  Bathrooms  \
# 0   5600000.0  Noida Extension, Noida, Delhi NCR  1350.0       3.0        3.0
# 1   8800000.0      Sector 79, Gurgaon, Delhi NCR  1490.0       3.0        3.0
# 2  16500000.0     Vaishali, Ghaziabad, Delhi NCR  2385.0       4.0        5.0
# 3   3810000.0                              other  1050.0       2.0        2.0
# 4   6200000.0                              other  1350.0       2.0        2.0
#
#                Status Furnished_status   Price_sqft
# 0  Under Construction      Unfurnished  4148.148148
# 1       Ready to Move   Semi-Furnished  5906.040268
# 2       Ready to Move      Unfurnished  6918.238994
# 3       Ready to Move      Unfurnished  3628.571429
# 4       Ready to Move      Unfurnished  4592.592593

# %%
data.to_csv('Cleaned.csv')

# %%
X = data.drop(columns =['price'])
y=data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6190, 7)
# (1548, 7)

# %%
column_trans = make_column_transformer((OneHotEncoder(),['Address','Status','Furnished_status']),remainder = 'passthrough')

# %%
scaler = StandardScaler(with_mean=False)

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train,y_train)
print(X_train.columns)
# Out:
# Index(['Address', 'area', 'Bedrooms', 'Bathrooms', 'Status',
#        'Furnished_status', 'Price_sqft'],
#       dtype='object')

# %%
print(X_train.dtypes)
# Out:
# Address              object
# area                float64
# Bedrooms            float64
# Bathrooms           float64
# Status               object
# Furnished_status     object
# Price_sqft          float64
# dtype: object

# %%
y_pred_lr = pipe.predict(X_test)

# %%
r2_score(y_test, y_pred_lr)
# Out:
# 0.9484960037085427

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['Address', 'Status',
#                                                    'Furnished_status'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('ridge', Ridge())])

# %%
y_pred_r = pipe.predict(X_test)

# %%
r2_score(y_test, y_pred_r)
# Out:
# 0.9485054212481324

# %%
import tensorflow as tf
from joblib import  load

# %%
import pickle

# %%
pickle.dump(pipe, open('housing.pkl', 'wb'))

# %%
model = load('housing.pkl')

# %%
converter = tf.lite.TFLiteConverter.from_sklearn(model)
tflite_model = converter.convert()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 converter = tf.lite.TFLiteConverter.from_sklearn(model)
#       2 tflite_model = converter.convert()
#
# AttributeError: type object 'TFLiteConverterV2' has no attribute 'from_sklearn'
